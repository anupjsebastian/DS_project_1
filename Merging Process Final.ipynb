# %%
import pandas as pd

# %%
earnings_df = pd.read_csv('2015 to 2019 earnings.csv')

# %%
earnings_df.head()
# Out:
#    Unnamed: 0                                       Title        Worldwide  \
# 0           0  Star Wars: Episode VII - The Force Awakens  $2,068,223,624
# 1           1                              Jurassic World  $1,670,400,637
# 2           2                                   Furious 7  $1,515,047,671
# 3           3                     Avengers: Age of Ultron  $1,402,805,868
# 4           4                                     Minions  $1,159,398,397
#
#         Domestic % Domestic          Foreign % Foreign
# 0  $936,662,225      45.30%  $1,131,561,399     54.70%
# 1  $652,270,625         39%  $1,018,130,012        61%
# 2  $353,007,020      23.30%  $1,162,040,651     76.70%
# 3  $459,005,868      32.70%    $943,800,000     67.30%
# 4  $336,045,770         29%    $823,352,627        71%

# %%
earnings_df = earnings_df.drop(labels = 'Unnamed: 0', axis = 1)

# %%
for column in list(earnings_df.columns):
    if column in exclude_list:
        continue
    else:
        if '.' not in earnings_df[column][0]:
            earnings_df[column] = earnings_df[column].map(lambda row: 0 if row == '-' else int(row.replace('$','').replace(',','')))
        else:
            earnings_df[column] = earnings_df[column].map(lambda row: 0 if row == '-' else float(row.replace('%', '').replace('<','')))

# %%
earnings_df.head()
# Out:
#                                         Title   Worldwide   Domestic  \
# 0  Star Wars: Episode VII - The Force Awakens  2068223624  936662225
# 1                              Jurassic World  1670400637  652270625
# 2                                   Furious 7  1515047671  353007020
# 3                     Avengers: Age of Ultron  1402805868  459005868
# 4                                     Minions  1159398397  336045770
#
#    % Domestic     Foreign  % Foreign
# 0        45.3  1131561399       54.7
# 1        39.0  1018130012       61.0
# 2        23.3  1162040651       76.7
# 3        32.7   943800000       67.3
# 4        29.0   823352627       71.0

# %%
flattenned_df = pd.read_csv('all_year_flat_03.csv')
# Out:
# C:\Users\anupj\Anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (7,23,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flattenned_df.columns[:40]
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1',
#        'Title', 'Actors', 'Awards', 'BoxOffice', 'Country', 'DVD', 'Director',
#        'Genre', 'Language', 'Metascore', 'Plot', 'Poster', 'Production',
#        'Rated', 'Ratings', 'Released', 'Response', 'Runtime', 'Type',
#        'Website', 'Writer', 'Year', 'imdbID', 'imdbRating', 'imdbVotes',
#        'index', 'level_0', 'totalSeasons', 'Worldwide', 'Domestic',
#        '% Domestic', 'Foreign', '% Foreign', 'Genre_Action', 'Genre_Family',
#        'Genre_Crime'],
#       dtype='object')

# %%
flattenned_df = flattenned_df.drop(labels = ['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1', 'Unnamed: 0.1.1.1',
       'Actors', 'BoxOffice',  'DVD','Genre', 'Plot', 'Poster', 'Production',
       'Rated', 'Ratings',  'Response',  'Type',
       'Website', 'Writer', 'index', 'level_0', 'totalSeasons', 'Worldwide', 'Domestic',
       '% Domestic', 'Foreign', '% Foreign'], axis = 1)

# %%
merged_complete = pd.merge(flattenned_df, earnings_df, on = ['Title'],  how = 'left')

# %%
merged_complete
# Out:
#                                            Title  \
# 0     Star Wars: Episode VII - The Force Awakens
# 1                                         Avatar
# 2                         Avengers: Infinity War
# 3                                   The Avengers
# 4        Star Wars: Episode VIII - The Last Jedi
# ...                                          ...
# 1405        You Are Here: A Come From Away Story
# 1406     ZZ Top: That Little Ol' Band from Texas
# 1407                             Zen for Nothing
# 1408                      Zombieland: Double Tap
# 1409                                         Ága
#
#                                                  Awards  \
# 0     Nominated for 5 Oscars. Another 57 wins & 123 ...
# 1      Won 3 Oscars. Another 85 wins & 128 nominations.
# 2                                                   NaN
# 3     Nominated for 1 Oscar. Another 38 wins & 79 no...
# 4     Nominated for 4 Oscars. Another 12 wins & 71 n...
# ...

# %%
idx = merged_complete['Worldwide'].isna()

# %%
merged_df = merged_complete[~idx]

# %%
merged_df.to_csv('interim_data.csv')
